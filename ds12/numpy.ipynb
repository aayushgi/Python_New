# %% [markdown]
# # Numpy

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import numpy as np 
b=np.array([[1,2,3,4],[5,6,7,8]])
print(b)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
print(a.ndim)
# Out:
# 1

# %%
print(b.ndim)
# Out:
# 2

# %%
print(a.shape)
# Out:
# (4,)

# %%
print(a.size)
# Out:
# 4

# %%
print(a.dtype)
# Out:
# int64

# %%
a1=np.zeros((2,3))
print(a1)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
a2=np.ones((3,3))
print(a2)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
a3=np.eye(3)
print(a3)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
a4=np.arange(1,10,2)
print(a4)
# Out:
# [1 3 5 7 9]

# %%
a5=np.linspace(1,3,3)
print(a5)
# Out:
# [1. 2. 3.]

# %%
a6=np.random.rand(3,3)
print(a6)
# Out:
# [[0.99500052 0.91711045 0.93223658]
#  [0.88625952 0.04468079 0.22041828]
#  [0.56074239 0.33291855 0.94810099]]

# %%
arr=np.array([10,20,30,40])
print(arr)
print(arr[3])
print(arr[1:4])
# Out:
# [10 20 30 40]
# 40
# [20 30 40]

# %%
mat=([[10,20,30,40],[50,60,70,80]])
print(mat)
print(mat[1:4])
# Out:
# [[10, 20, 30, 40], [50, 60, 70, 80]]
# [[50, 60, 70, 80]]

# %%
a=np.array([1,2,3])
b=np.array([4,5,6])
print(a+b)
print(a-b)
print(a**2)
print(a*b)
print(a/b)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [1 4 9]
# [ 4 10 18]
# [0.25 0.4  0.5 ]

# %%
a=np.array([1,2,3,4,5])
print(np.max(a))
print(np.min(a))
print(np.std(a))
print(np.sum(a))
print(np.mean(a))
# Out:
# 5
# 1
# 1.4142135623730951
# 15
# 3.0

# %%
a=np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
print(np.dot(a,b))
print(np.linalg.det(a))
print(np.linalg.inv(a))
# Out:
# [[19 22]
#  [43 50]]
# -2.0000000000000004
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
arr=np.array([12,12,13,14,15])
print(np.min(arr))
