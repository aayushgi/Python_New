# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("car_price_dataset.csv")
df.head(5)
# Out:
#    Car_Age  KM_Driven Fuel_Type  Owner_Type  Mileage  Engine_Size   Price
# 0        1      12000    Petrol           1       20         1200  720000
# 1        2      18000    Petrol           1       19         1200  680000
# 2        3      25000    Diesel           1       22         1500  650000
# 3        4      30000    Diesel           2       21         1500  620000
# 4        5      40000    Petrol           2       18         1300  580000

# %%
X=df.iloc[:,:6].values
y=df.iloc[:,6].values

# %%
#encode dataset using lableencoder
#converting into 0/1
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X[:,2]=le.fit_transform(X[:,2])

# %%
X
# Out:
# array([[1, 2, 1, 1, 20, 1200],
#        [2, 8, 1, 1, 19, 1200],
#        [3, 16, 0, 1, 22, 1500],
#        [4, 24, 0, 2, 21, 1500],
#        [5, 32, 1, 2, 18, 1300],
#        [6, 40, 0, 2, 20, 1500],
#        [7, 48, 0, 3, 19, 1600],
#        [8, 56, 1, 2, 17, 1300],
#        [9, 64, 0, 3, 18, 1600],
#        [10, 72, 1, 3, 16, 1200],
#        [1, 7, 1, 1, 21, 1200],
#        [2, 11, 0, 1, 22, 1500],
#        [3, 19, 1, 1, 19, 1300],
#        [4, 29, 0, 2, 21, 1500],
#        [5, 35, 1, 2, 18, 1300],
#        [6, 43, 0, 2, 20, 1500],
#        [7, 53, 0, 3, 19, 1600],
#        [8, 59, 1, 2, 17, 1300],
#        [9, 67, 0, 3, 18, 1600],
#        [10, 75, 1, 3, 16, 1200],
#        [1, 0, 1, 1, 21, 1200],
#        [2, 9, 0, 1, 22, 1500],
#        [3, 17, 1, 1, 19, 1300],
#        [4, 25, 0, 2, 21, 1500],
#        [5, 33, 1, 2, 18, 1300],
#        [6, 41, 0, 2, 20, 1500],
#        [7, 49, 0, 3, 19, 1600],
#        [8, 57, 1, 2, 17, 1300],
#        [9, 65, 0, 3, 18, 1600],
#        [10, 73, 1, 3, 16, 1200],
#        [1, 5, 1, 1, 20, 1200],
#        [2, 14, 0, 1, 22, 1500],
#        [3, 22, 1, 1, 19, 1300],
#        [4, 30, 0, 2, 21, 1500],
#        [5, 38, 1, 2, 18, 1300],
#        [6, 46, 0, 2, 20, 1500],
#        [7, 54, 0, 3, 19, 1600],
#        [8, 62, 1, 2, 17, 1300],
#        [9, 70, 0, 3, 18, 1600],
#        [10, 78, 1, 3, 16, 1200],
#        [1, 6, 1, 1, 21, 1200],
#        [2, 15, 0, 1, 22, 1500],
#        [3, 23, 1, 1, 19, 1300],
#        [4, 31, 0, 2, 21, 1500],
#        [5, 39, 1, 2, 18, 1300],
#        [6, 47, 0, 2, 20, 1500],
#        [7, 55, 0, 3, 19, 1600],
#        [8, 63, 1, 2, 17, 1300],
#        [9, 71, 0, 3, 18, 1600],
#        [10, 79, 1, 3, 16, 1200],
#        [1, 4, 1, 1, 21, 1200],
#        [2, 13, 0, 1, 22, 1500],
#        [3, 21, 1, 1, 19, 1300],
#        [4, 28, 0, 2, 21, 1500],
#        [5, 37, 1, 2, 18, 1300],
#        [6, 45, 0, 2, 20, 1500],
#        [7, 52, 0, 3, 19, 1600],
#        [8, 60, 1, 2, 17, 1300],
#        [9, 68, 0, 3, 18, 1600],
#        [10, 76, 1, 3, 16, 1200],
#        [1, 1, 1, 1, 21, 1200],
#        [2, 10, 0, 1, 22, 1500],
#        [3, 18, 1, 1, 19, 1300],
#        [4, 26, 0, 2, 21, 1500],
#        [5, 34, 1, 2, 18, 1300],
#        [6, 42, 0, 2, 20, 1500],
#        [7, 50, 0, 3, 19, 1600],
#        [8, 58, 1, 2, 17, 1300],
#        [9, 66, 0, 3, 18, 1600],
#        [10, 74, 1, 3, 16, 1200],
#        [1, 3, 1, 1, 21, 1200],
#        [2, 12, 0, 1, 22, 1500],
#        [3, 20, 1, 1, 19, 1300],
#        [4, 27, 0, 2, 21, 1500],
#        [5, 36, 1, 2, 18, 1300],
#        [6, 44, 0, 2, 20, 1500],
#        [7, 51, 0, 3, 19, 1600],
#        [8, 61, 1, 2, 17, 1300],
#        [9, 69, 0, 3, 18, 1600],
#        [10, 77, 1, 3, 16, 1200]], dtype=object)

# %%
y
# Out:
# array([720000, 680000, 650000, 620000, 580000, 540000, 500000, 470000,
#        430000, 400000, 710000, 670000, 640000, 610000, 570000, 530000,
#        495000, 460000, 425000, 395000, 725000, 690000, 660000, 630000,
#        590000, 550000, 510000, 480000, 440000, 410000, 715000, 675000,
#        645000, 615000, 575000, 535000, 505000, 475000, 435000, 405000,
#        705000, 665000, 635000, 605000, 565000, 525000, 495000, 465000,
#        425000, 395000, 720000, 680000, 650000, 620000, 580000, 540000,
#        500000, 470000, 430000, 400000, 718000, 678000, 648000, 618000,
#        578000, 538000, 498000, 468000, 428000, 398000, 722000, 682000,
#        652000, 622000, 582000, 542000, 502000, 472000, 432000, 402000])

# %%
#split data set into taraining and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)
X_test=ss.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([708511.65403916, 463021.12848804, 474420.47356452, 662051.67718384,
#        513869.95309941, 521469.51648373, 719910.99911564, 625363.2552961 ,
#        415985.35680533, 327263.42237031, 563704.15167214, 565604.04251822,
#        612064.01937354, 569403.82421038, 672286.16136904, 476320.3644106 ])

# %%
y_test
# Out:
# array([665000, 495000, 510000, 645000, 535000, 538000, 690000, 620000,
#        475000, 395000, 565000, 575000, 605000, 582000, 650000, 500000])

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print("accuracy",r2)
# Out:
# accuracy 0.836464592151831
