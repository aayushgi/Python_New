# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("loan_approval_data.csv")

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        950 non-null    float64
#  1   Applicant_Income    950 non-null    float64
#  2   Coapplicant_Income  950 non-null    float64
#  3   Employment_Status   950 non-null    str
#  4   Age                 950 non-null    float64
#  5   Marital_Status      950 non-null    str
#  6   Dependents          950 non-null    float64
#  7   Credit_Score        950 non-null    float64
#  8   Existing_Loans      950 non-null    float64
#  9   DTI_Ratio           950 non-null    float64
#  10  Savings             950 non-null    float64
#  11  Collateral_Value    950 non-null    float64
#  12  Loan_Amount         950 non-null    float64
#  13  Loan_Term           950 non-null    float64
#  14  Loan_Purpose        950 non-null    str
#  15  Property_Area       950 non-null    str
#  16  Education_Level     950 non-null    str
#  17  Gender              950 non-null    str
#  18  Employer_Category   950 non-null    str
#  19  Loan_Approved       950 non-null    str
# dtypes: float64(12), str(8)
# memory usage: 205.3 KB

# %%
df.head(20)
# Out:
#     Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0            1.0           17795.0              1387.0          Salaried
# 1            2.0            2860.0              2679.0          Salaried
# 2            3.0            7390.0              2106.0          Salaried
# 3            4.0           13964.0              8173.0          Salaried
# 4            5.0           13284.0              4223.0     Self-employed
# 5            6.0            8265.0              4831.0          Salaried
# 6            7.0           18850.0              2768.0          Salaried
# 7            8.0            6426.0              3186.0          Salaried
# 8            9.0           16423.0                 NaN          Salaried
# 9           10.0           13363.0              2599.0          Contract
# 10          11.0           18023.0              4033.0          Salaried
# 11          12.0           10322.0              8428.0     Self-employed
# 12          13.0            3685.0              1304.0          Contract
# 13          14.0            2769.0              7368.0     Self-employed
# 14          15.0            4433.0              5877.0          Contract
# 15          16.0            7311.0              1301.0          Salaried
# 16          17.0            7051.0              2541.0        Unemployed
# 17          18.0            8420.0              2051.0          Salaried
# 18          19.0           19568.0              6809.0          Salaried
# 19          20.0            8396.0              8633.0               NaN
#
#      Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0   51.0        Married         0.0         637.0             4.0       0.53
# 1   46.0        Married         3.0         621.0             2.0       0.30
# 2   25.0         Single         2.0         674.0             4.0       0.20
# 3   40.0        Married         2.0         579.0             3.0       0.31
# 4   31.0         Single         2.0         721.0             1.0       0.29
# 5   53.0         Single         1.0         602.0             1.0       0.56
# 6   58.0        Married         0.0         687.0             0.0       0.48
# 7   47.0        Married         2.0         636.0             4.0        NaN
# 8   54.0        Married         1.0         729.0             0.0       0.59
# 9   35.0         Single         3.0         726.0             1.0        NaN
# 10  52.0        Married         2.0         688.0             1.0       0.13
# 11  41.0            NaN         1.0         743.0             4.0       0.23
# 12  25.0        Married         2.0         735.0             3.0       0.32
# 13  26.0         Single         0.0         767.0             3.0       0.18
# 14  58.0         Single         0.0         713.0             4.0       0.57
# 15  42.0        Married         3.0         710.0             4.0       0.48
# 16  38.0            NaN         2.0         724.0             0.0       0.23
# 17  34.0        Married         1.0         562.0             4.0       0.40
# 18  30.0        Married         3.0         589.0             3.0       0.46
# 19  33.0         Single         2.0         638.0             NaN       0.57
#
#     Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0   19403.0           45638.0      16619.0       84.0     Personal
# 1    2580.0           49272.0      38687.0        NaN          Car
# 2   13844.0            6908.0      27943.0       72.0          NaN
# 3    9553.0           10844.0      27819.0       60.0     Business
# 4    9386.0           37629.0      12741.0       72.0          Car
# 5   19522.0            2911.0       9798.0       36.0         Home
# 6   14635.0            8991.0      26143.0       24.0         Home
# 7     671.0           11572.0      33747.0       84.0     Personal
# 8     777.0           43066.0      34651.0       36.0         Home
# 9    3022.0           29693.0      22182.0       60.0     Personal
# 10  18244.0           40004.0      10415.0       12.0    Education
# 11      NaN           38333.0      12085.0       84.0          Car
# 12  13817.0           17493.0      16008.0       36.0     Business
# 13  14260.0           39697.0      23102.0       72.0     Personal
# 14   1074.0               NaN      19452.0       84.0          NaN
# 15   9908.0           24561.0       9120.0       72.0     Personal
# 16   9475.0           18033.0       8820.0       48.0     Personal
# 17  12878.0            7351.0      19170.0       48.0         Home
# 18  15120.0           25921.0      17259.0       48.0         Home
# 19   1986.0           19340.0      23099.0       84.0          Car
#
#    Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0          Urban    Not Graduate  Female           Private            No
# 1      Semiurban        Graduate     NaN           Private            No
# 2          Urban             NaN  Female        Government           Yes
# 3          Rural        Graduate  Female        Government            No
# 4            NaN        Graduate    Male           Private           Yes
# 5      Semiurban        Graduate    Male        Unemployed            No
# 6          Rural        Graduate    Male           Private            No
# 7          Rural        Graduate  Female               NaN            No
# 8      Semiurban        Graduate    Male           Private            No
# 9          Rural        Graduate  Female        Government           Yes
# 10         Urban    Not Graduate  Female               MNC           Yes
# 11     Semiurban        Graduate    Male        Government           Yes
# 12         Rural        Graduate    Male           Private            No
# 13     Semiurban        Graduate    Male           Private            No
# 14     Semiurban             NaN    Male               MNC            No
# 15         Urban    Not Graduate  Female           Private           NaN
# 16         Urban        Graduate  Female           Private           Yes
# 17         Urban        Graduate    Male           Private            No
# 18         Rural    Not Graduate  Female           Private            No
# 19         Urban        Graduate    Male           Private            No

# %% [markdown]
# # Handling the missing values

# %%
catogarical_cols=df.select_dtypes(include=["object"]).columns
numerical_cols=df.select_dtypes(include=["number"]).columns
# Out:
# C:\Users\mrayu\AppData\Local\Temp\ipykernel_24388\367273052.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   catogarical_cols=df.select_dtypes(include=["object"]).columns

# %%
from sklearn.impute import SimpleImputer
num_imp=SimpleImputer(strategy="mean")
df[numerical_cols]=num_imp.fit_transform(df[numerical_cols])

# %%
df.head(20)
# Out:
#     Applicant_ID  Applicant_Income  Coapplicant_Income Employment_
property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0          Urban    Not Graduate  Female           Private            No
# 1      Semiurban        Graduate     NaN           Private            No
# 2          Urban             NaN  Female        Government           Yes
# 3          Rural        Graduate  Female        Government            No
# 4            NaN        Graduate    Male           Private           Yes
# 5      Semiurban        Graduate    Male        Unemployed            No
# 6          Rural        Graduate    Male           Private            No
# 7          Rural        Graduate  Female               NaN            No
# 8      Semiurban        Graduate    Male           Private            No
# 9          Rural        Graduate  Female        Government           Yes
# 10         Urban    Not Graduate  Female               MNC           Yes
# 11     Semiurban        Graduate    Male        Government           Yes
# 12         Rural        Graduate    Male           Private            No
# 13     Semiurban        Graduate    Male           Private            No
# 14     Semiurban             NaN    Male               MNC            No
# 15         Urban    Not Graduate  Female           Private           NaN
# 16         Urban        Graduate  Female           Private           Yes
# 17         Urban        Graduate    Male           Private            No
# 18         Rural    Not Graduate  Female           Private            No
# 19         Urban        Graduate    Male           Private            No

# %%
cat_imp=SimpleImputer(strategy="most_frequent")
df[catogarical_cols]=cat_imp.fit_transform(df[catogarical_cols])

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0  19403.0           45638.0      16619.0       84.0     Personal
# 1   2580.0           49272.0      38687.0       48.0          Car
# 2  13844.0            6908.0      27943.0       72.0     Business
# 3   9553.0           10844.0      27819.0       60.0     Business
# 4   9386.0           37629.0      12741.0       72.0          Car
#
#   Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0         Urban    Not Graduate  Female           Private            No
# 1     Semiurban        Graduate    Male           Private            No
# 2         Urban        Graduate  Female        Government           Yes
# 3         Rural        Graduate  Female        Government            No
# 4         Urban        Graduate    Male           Private           Yes

# %%
df.isnull().sum()
# Out:
# Applicant_ID          0
# Applicant_Income      0
# Coapplicant_Income    0
# Employment_Status     0
# Age                   0
# Marital_Status        0
# Dependents            0
# Credit_Score          0
# Existing_Loans        0
# DTI_Ratio             0
# Savings               0
# Collateral_Value      0
# Loan_Amount           0
# Loan_Term             0
# Loan_Purpose          0
# Property_Area         0
# Education_Level       0
# Gender                0
# Employer_Category     0
# Loan_Approved         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
# how balanced our classes are
classes_count=df["Loan_Approved"].value_counts()
plt.pie(classes_count,labels=["No","Yes"],autopct="%1.1f%%")
plt.title("is loan approved?")
# Out:
# Text(0.5, 1.0, 'is loan approved?')

# %%
#analyze catogries
gender_count=df["Gender"].value_counts()
axs=sns.barplot(gender_count)
axs.bar_label(axs.containers[0])


edu_count=df["Education_Level"].value_counts()
axs=sns.barplot(edu_count)
axs.bar_label(axs.containers[0])
# Out:
# [Text(0, 0, '621'), Text(0, 0, '379')]

# %%
#analyze income
sns.histplot(
    data=df,
    x="Applicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
#analyze income
sns.histplot(
    data=df,
    x="Coapplicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Coapplicant_Income', ylabel='Count'>

# %%
# outlires box plots
sns.boxplot(
    data=df,
    x="Loan_Approved"
)
